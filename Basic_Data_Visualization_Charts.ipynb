# %% [markdown]
# <a href="https://colab.research.google.com/github/jrtejaswini/DATA-SCIENCE-AND-ANALYTICS-/blob/main/Basic_Data_Visualization_Charts.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt


data = {'Category': ['A', 'B', 'C', 'D'], 'Values': [10, 25, 15, 30]}
df = pd.DataFrame(data)


plt.figure(figsize=(8, 4))
plt.bar(df['Category'], df['Values'], color='skyblue')
plt.title('Basic Bar Chart')
plt.xlabel('Category')
plt.ylabel('Values')
plt.show()


plt.figure(figsize=(8, 4))
plt.plot(df['Category'], df['Values'], marker='o', linestyle='-', color='green')
plt.title('Basic Line Chart')
plt.show()


plt.figure(figsize=(6, 6))
plt.pie(df['Values'], labels=df['Category'], autopct='%1.1f%%')
plt.title('Basic Pie Chart')
plt.show()
